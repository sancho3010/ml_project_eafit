# %%
import sys
import os
from pathlib import Path

sys.path.insert(0, str(Path(os.getcwd()).parent / 'src'))

from download_data import download_all, URL_BASE, LIMIT, OUTPUT_DIR
from loguru import logger

# %%
download_all(
    url_base=URL_BASE,
    limit=LIMIT,
    output_dir=OUTPUT_DIR,
)
# Out:
# 2026-04-26 22:24:42.931 | INFO     | download_data:download_all:99 - Retomando desde lote 0143 | offset 7150000
# 2026-04-26 22:24:42.932 | INFO     | download_data:get_data_batch:45 - Se definieron 3 intentos para este lote...
# 2026-04-26 22:24:50.111 | INFO     | download_data:get_data_batch:56 - Descarga completa
# 2026-04-26 22:24:50.113 | INFO     | download_data:download_all:125 - Descarga finalizada. 143 lotes guardados en /Users/santiago.higuitau/Documents/Machine_Learning/ml_project_eafit/data/raw
